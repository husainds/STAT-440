# %% [markdown]
# # STAT 440 Statistical Data Management - Summer 2020
# ## Homework 1 **Solutions**
# ### Due: Monday June 22, 2020 11:50 pm Central Daylight Time
# #### Created by Instructor and CAs
#
#
# Grading Rubric (per question):
# 2 points if complete and correct
# 1 point if incomplete or incorrect
# 0 points if no attempt made
#
#
# **Retrieving your work**
#
# This and all future homework .md files are written in Markdown. The .md file is rendered as an .html file for easier viewing. This and all future homework files will exist in Compass. Once you have downloaded the .md file, copy all text from the .md file and paste all text into your reproducible document file (either .Rmd or .ipynb file).
#
# **Submitting your work**
#
# In Compass, you are to submit **one** zipped file which contains ***two*** files.
#
# a. Your reproducible document file (either .Rmd or .ipynb) which should be saved as either hw#_netID.Rmd or hw#_netID.ipynb depending on your preferred software. For example, if I prefer to use R with RMarkdown as my software, then my homework 1 file would be saved as hw1_kinson2.Rmd.
#
# b. Your rendered reproducible document file (.html) which should be saved as hw#_netID.html. For example, if I prefer to use R with RMarkdown as my software, then my homework 1 file would be saved as hw1_kinson2.html.
#
# You have an unlimited number of submissions, but only the latest proper submission (the one .zip which contains those two files) will be viewed and graded. You are allowed to only use one software language per homework file. This means that you cannot mix software languages (R, Python, SAS) in one single homework file. Remember the .Rmd or .ipynb file needs to render properly to .html before you zip and submit them.
#
#
# ***
#
# Undergraduates are expected to complete the problems **#0-#8**. Graduate students are expected to complete all problems.
#
# *The following problems should be completed by you as an individual. If any problem asks you a particular question, be sure to answer it completely (with code, written sentences, or both). Written sentences should not appear in code chunks or code cells. Written sentences should appear in Markdown syntax unless specifically stated otherwise. Students are encouraged to openly and productively discuss the homework using the **Students to Students Forum** in Compass. However, sharing or copying any part of the homework is an infraction of the University's rules on Academic Integrity. Do not change anything in this file above the double line.*
#
# ***
# ***
#
# ### Use only one programming language for this entire homework assignment. Use the URLs to access the data. No local files allowed.
#
# **#1** (Markdown) Using Markdown syntax, make a numbered list with your first name in normal text as the first item and your last name in bold text as the second item.
#
# ***Answers will vary. Graded for completeness (must be a list).***
#
# 1. FirstName
# 2. **LastName**
#
# **#2** (Prior knowledge about using Box, Markdown) Take a selfie showing your uncovered face and holding up the number 1 with your right hand. Store the image in your U of I Box account. Next, create a Box link to your image, and show the image as the answer to this problem using the Box link. The image insertion should be done using Markdown syntax. *If you have not created a U of I Box account, please create one by turning the U of I Box service "On" using https://cloud-dashboard.illinois.edu/.*
#
# ![](https://uofi.box.com/shared/static/sledrftsq1f7gpago3rglf5valosobuj.jpg)
#
# **#3** (Syllabus, Markdown) All assignments are assumed to be in which time zone?
#
# ***Two acceptable answers: US Central Time or Central Daylight Time***
#
# **#4** (Syllabus, Markdown) In an unordered list, write the names of the teaching assistant (TA) and course assistants (CAs) for this course?
#
# ***There are no teaching assistants, but there are 3 course assistants.***
#
# - Suyoung Park
# - Luyu Zhang
# - Kexin Yang
#
# **#5** (Prior knowledge about software, Markdown) Of the three available software languages - R, Python, and SAS - list them in order of your preference to use in this course, such that the first item is your most preferred and three is your least preferred.
#
# ***Answers will vary. Graded for completeness (must be a list).***
#
# i. R
# ii. SAS
# iii. Python
#
# **#6** (Prior knowledge about data, Markdown) Consider the information in the image below and the image itself as a data set. ***An image of The Everything Giant Book of Word Searches by C. Timmerman***. Make 2 lists: one list contains 3 things you know to be true about the data set, and the other list contains 3 questions about the data set (things you want to know).
#
# ![](https://uofi.box.com/shared/static/sr0okcjrb7uw9lintsaxocrkpvy7ko8t.jpg)
#
# ***Answers will vary. Graded for completeness (must be two lists).***
#
# a. Data is a crossword puzzle that has been completed.
# b. The puzzle is on page 18
# c. The image is KB in size.
#
# d. Why are there angled rays or lines next to each word in the list?
# e. What is the Blondie Comic Strip?
# f. Are all the words actually found in the puzzle or just on the list?
#
# **#7** (Prior knowledge about data, Markdown) Considering the image in **Problem 6** and using Markdown syntax, create a table that shows how you would organize the data set into tabular form with at least 10 rows and at least 2 columns with column names.
#
# ***Answers will vary. Graded for completeness (must be a table with 10 rows and at least 2 columns with column names).***
#
# Word | Orientation in Puzzle |
# ---|---|
# ALEXANDER | top-left to bottom-right
# AMERICAN | left to right
# BABY DUMPLING | bottom-right to top-left
# BATHTUB | top-right to bottom-left
# BLONDIE | right to left
# BOOPADOOP | top-left to bottom-right
# BOSS | left to right
# BUMSTEAD FAMILY | top-left to bottom-right
# CARPOOL | top to bottom
# CARTOON | right to left
#
# **#8** (Prior knowledge about data, Markdown) Consider the information in the image below and the image itself as a data set. ***An image of The New York Times What's Going on in this Graph.*** Make 2 lists: one list contains 3 things you know to be true about the data set, and the other list contains 3 questions about the data set (things you want to know).
#
# ![](https://static01.nyt.com/images/2019/01/17/world/17scarf-print-LN/17scarf-print-LN-superJumbo-v3.jpg?quality=90&auto=webp)
#
# ***Answers will vary. Graded for completeness (must be two lists).***
#
# a. Data is a fabric material.
# b. The background is parquet wood flooring.
# c. The fabric has multiple colors taking up varying amounts of material.
#
# d. What is this product?
# e. Is the product completed or still a work in progress?
# f. What information is being stored in this fabric?
#
# **#9** (Prior knowledge about data, Markdown) Consider the information in the image in **Problem 8** and the image itself as a data set. How would you would organize the data set into tabular form (with rows and columns)? What would be the column names? What are the observations?
#
# ***Answers will vary. Graded for completeness (must answer all 3 questions).***
#
# I would organize the data set in the following manner: the observations (rows) are colors and the variables (columns) are attributes for the colors such as length and width. The observations are likely not independent.
#
# **#10** (Prior knowledge about data, Markdown) Considering your idea for an organized tabular form of the data in **Problem 9**, describe:
#
# - a kind of data analysis that is sensible for this data set
#
# - what information is needed to help improve the data so that more analysis can be done.
#
# ***Answers will vary. Graded for completeness (must describe all 3).***
#
# A longitudinal data analysis or time series might be sensible for this data set. Some information that may improve the data for more analysis might be:
# - identification of the observations to determine if these are dependent or not
# - the data size (total number of observations and columns)
